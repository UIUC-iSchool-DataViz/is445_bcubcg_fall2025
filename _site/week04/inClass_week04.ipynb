# %% [markdown]
# # In Class Notebook, Week 04

# %% [markdown]
# To access this notebook in near-real time try: https://github.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2025/blob/master/week04/inClass_week04.ipynb

# %%
import matplotlib.pyplot as plt

# %%
import PIL.Image as Image

# %%
#!wget https://github.com/UIUC-iSchool-DataViz/is445_data/raw/main/stitch_reworked.png

# %%
# !ls ~/Downloads/stitch_reworked.png
# Out:
# /Users/jnaiman/Downloads/stitch_reworked.png

# %%
# !ls
# Out:
# __pycache__
# _lecture03p3_extras.md
# _test_widgets.ipynb
# diagrams
# fall2019_prep_notebook_furtherExamples_01.ipynb
# fall2019_prep_notebook_furtherExamples_02.ipynb
# fall2019_prep_notebook_furtherExamples_03.ipynb
# fall2019_prep_notebook_week03.ipynb
# images
# inClass_week04.ipynb
# index.md
# lecture03p1.md
# lecture03p1.md~
# lecture03p2.md
# library
# littleCorgiInHat.png
# prep_notebook_week04.ipynb
# spring2019_prep_notebook_furtherExamples_week03.ipynb
# spring2019_prep_notebook_week03_part2.ipynb
# stitch_reworked.png

# %%
im = Image.open('./stitch_reworked.png') # if I used wget, local image

# %%
im = Image.open('/Users/jnaiman/Downloads/stitch_reworked.png') # in downloads directory

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=430x483>

# %%
type(im)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
import numpy as np

# %%
im_data = np.array(im)

# %%
im_data.shape # 483 rows, 430 columns, 4 color channels -- R=red, G=Green, B=blue, A=alpha/opacity
# Out:
# (483, 430, 4)

# %%
fig, ax = plt.subplots(figsize=(10,2))
ax.hist(im_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 fig, ax = plt.subplots(figsize=(10,2))
# ----> 2 ax.hist(im_data)
#       3 plt.show()
#
# File /opt/anaconda3/envs/DataViz/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/envs/DataViz/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6554, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6551     stacked = True
#    6553 # Massage 'x' for processing.
# -> 6554 x = cbook._reshape_2D(x, 'x')
#    6555 nx = len(x)  # number of datasets
#    6557 # Process unit information.  _process_unit_info sets the unit and
#    6558 # converts the first dataset; then we convert each following dataset
#    6559 # one at a time.
#
# File /opt/anaconda3/envs/DataViz/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1344, in _reshape_2D(X, name)
#    1342         return [np.reshape(x, -1) for x in X]
#    1343     else:
# -> 1344         raise ValueError(f'{name} must have 2 or fewer dimensions')
#    1346 # Iterate over list of iterables.
#    1347 if len(X) == 0:
#
# ValueError: x must have 2 or fewer dimensions
