# %% [markdown]
# # In Class Notebook, Week 06

# %% [markdown]
# You can click on the GitHub URL of this notebook to access the file in near-real time: https://github.com/UIUC-iSchool-DataViz/is445_bcubcg_fall2025/blob/master/week06/inClass_week06.ipynb

# %%
import ipywidgets

# %%
islider = ipywidgets.IntSlider(min=0, max=10, step=1, orientation='vertical')
#islider

# %%
cp = ipywidgets.ColorPicker()
#cp

# %%
ipywidgets.link( (cp, 'value'), (islider.style, 'handle_color'))

# %%
ipywidgets.HBox([cp, islider])
# Out:
# HBox(children=(ColorPicker(value='black'), IntSlider(value=0, max=10, orientation='vertical', style=SliderStyl…

# %%
class MyObject():
    name = 'unnamed'
    age = 0

# %%
my_obj = MyObject()

# %%
my_obj.name, my_obj.age
# Out:
# ('unnamed', 0)

# %%
my_obj.name = 'Bob'
my_obj.age = 47

# %%
print('Hello, my name is', my_obj.name, 'and I am', my_obj.age, 'years old.')
# Out:
# Hello, my name is Bob and I am 47 years old.

# %%
# class MyObject():
#     name = 'unnamed'
#     age = 0

import traitlets

# %%
class MyTraitletObject(traitlets.HasTraits):
    name = traitlets.Unicode('unnamed') # string
    age = traitlets.Int(0) # integer

# %%
my_t_obj = MyTraitletObject()

# %%
my_t_obj.name, my_t_obj.age
# Out:
# ('unnamed', 0)

# %%
def name_changed(change): # event? change?
    print(change)

my_t_obj.observe(name_changed, ['name'])

# %%
my_t_obj.name = 'Linda'
# Out:
# {'name': 'name', 'old': 'unnamed', 'new': 'Linda', 'owner': <__main__.MyTraitletObject object at 0x106df4b20>, 'type': 'change'}

# %%
def name_changed2(change): # event? change?
    #print(change)
    print('Hello, my name is', change['new'], 'and I am', change['owner'].age, 'years old.')

my_t_obj.observe(name_changed2, ['name'])

# %%
my_t_obj.name = 'Linda'
# Out:
# {'name': 'name', 'old': 'Bob', 'new': 'Linda', 'owner': <__main__.MyTraitletObject object at 0x106df4b20>, 'type': 'change'}
# Hello, my name is Linda and I am 0 years old.
# Hello, my name is Linda and I am 0 years old.

# %%
my_t_obj.unobserve(name_changed2, ['name'])

# %%
my_t_obj = MyTraitletObject()

def name_changed(change): 
    print('Hello, my name is', change['new'], 'and I am', change['owner'].age, 'years old.')

my_t_obj.observe(name_changed, ['name'])

# %%
my_t_obj.name = 'Linda'
# Out:
# Hello, my name is Linda and I am 0 years old.

# %%
my_t_obj.name = 'Linda'

# %%
def age_changed(change):
    print('Hello, my name is', change['owner'].name, 'and I am', change['new'], 'years old.')

my_t_obj.observe(age_changed, ['age'])

# %%
my_t_obj.age = 45
# Out:
# Hello, my name is Linda and I am 45 years old.

# %%
my_t_obj.name = 'Bob'
my_t_obj.age = 47
# Out:
# Hello, my name is Bob and I am 45 years old.
# Hello, my name is Bob and I am 47 years old.

# %% [markdown]
# ## Intro to bqplot

# %%
import bqplot

# %%
import numpy as np

# %%
# 1. Data
x = np.arange(100)
y = np.random.random(100)

# %%
y
# Out:
# array([0.09753739, 0.84641986, 0.73163553, 0.31333005, 0.54441096,
#        0.9333227 , 0.66293585, 0.38586187, 0.08968282, 0.03802077,
#        0.98495946, 0.89664655, 0.74782454, 0.48591156, 0.52104594,
#        0.30051293, 0.27023426, 0.02627794, 0.3003268 , 0.82676014,
#        0.19059018, 0.9078082 , 0.60697466, 0.51864632, 0.93036261,
#        0.99534596, 0.12039686, 0.40996987, 0.92587966, 0.80987685,
#        0.62398918, 0.37644661, 0.24689132, 0.93064714, 0.08607303,
#        0.33293228, 0.7386901 , 0.65800609, 0.7592692 , 0.54293892,
#        0.87338529, 0.67686048, 0.65833502, 0.60803553, 0.58329171,
#        0.36204822, 0.93991595, 0.71866299, 0.37273552, 0.21169114,
#        0.3519621 , 0.09959325, 0.84256466, 0.72812206, 0.93926879,
#        0.21756214, 0.67959772, 0.92080138, 0.79616812, 0.77987566,
#        0.73052007, 0.85688077, 0.83772912, 0.07915901, 0.31553229,
#        0.28848856, 0.67569759, 0.5746283 , 0.20286727, 0.98753122,
#        0.19999873, 0.52406555, 0.99468197, 0.39121929, 0.81190874,
#        0.5890055 , 0.48780031, 0.6179232 , 0.19528331, 0.52448337,
#        0.74305242, 0.73152096, 0.26297808, 0.01637283, 0.39050583,
#        0.43749732, 0.29372053, 0.87952894, 0.83877345, 0.35650728,
#        0.92045195, 0.70272462, 0.02084965, 0.35888128, 0.91434031,
#        0.90766701, 0.08703755, 0.86808578, 0.39038439, 0.9438023 ])
